# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model


from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv1D, LSTM, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import ReduceLROnPlateau


from sklearn.ensemble import RandomForestClassifier
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Flatten

from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# #Criando Features e Tratando os dados

# %%
# Função para criar novas features: desvio padrão, variancia e tendência de alta ou baixa.
def add_features(df):

    df['std_15_days'] = df[[f'Past_{i}_Days_Close' for i in range(1, 16)]].std(axis=1)
    df['variance_15_days'] = df[[f'Past_{i}_Days_Close' for i in range(1, 16)]].var(axis=1)


    #Tendências: Dias consecutivos de alta e baixa
    df['up_streak'] = df[[f'Past_{i}_Days_Close' for i in range(1, 16)]].apply(
        lambda row: sum(1 for i in range(14) if row[i] > row[i + 1]), axis=1
    )
    df['down_streak'] = df[[f'Past_{i}_Days_Close' for i in range(1, 16)]].apply(
        lambda row: sum(1 for i in range(14) if row[i] < row[i + 1]), axis=1
    )

    return df

# Função para carregar os arquivos e remover as colunas 'Unnamed: 0', 'Close', 'Smoothed_Close'
def load_and_preprocess_data(file_path):


    df = pd.read_csv(file_path)

    colunas_para_remover = ['Unnamed: 0', 'Close', 'Smoothed_Close']
    df = df.drop(columns=colunas_para_remover)

    # Função de adicionar novas features
    df = add_features(df)

    # Separar features e label
    X = df.drop(columns=['Date', 'Label']).values  # Remover colunas irrelevantes e label
    y = df['Label'].values  # A coluna "Label"

    # Normalização
    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    # Ajustar dimensões para redes neurais.
    X = X.reshape(X.shape[0], X.shape[1], 1)

    # Converter os labels para categórico.
    y = to_categorical((y + 1) // 2)

    return X, y

# Carregar dados de treino e teste
X_train, y_train = load_and_preprocess_data('treino.csv')
X_test, y_test = load_and_preprocess_data('teste.csv')
# Out:
# <ipython-input-3-35ac6086fd6a>:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda row: sum(1 for i in range(14) if row[i] > row[i + 1]), axis=1
# <ipython-input-3-35ac6086fd6a>:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda row: sum(1 for i in range(14) if row[i] < row[i + 1]), axis=1
# <ipython-input-3-35ac6086fd6a>:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda row: sum(1 for i in range(14) if row[i] > row[i + 1]), axis=1
# <ipython-input-3-35ac6086fd6a>:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda row: sum(1 for i in range(14) if row[i] < row[i + 1]), axis=1

# %% [markdown]
# # Modelo CNN

# %%
# Construção do modelo CNN
cnn_model = Sequential([
    Conv1D(filters=64, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], 1)),
    BatchNormalization(),  # Normaliza as ativações da camada
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    BatchNormalization(),

    MaxPooling1D(pool_size=1),
    Dropout(0.4),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')  # 2 classes: comprar/vender
])

# Compilação do modelo
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callback.
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

cnn_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30, batch_size=64, callbacks=[reduce_lr])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6083 - loss: 1.0104 - val_accuracy: 0.5978 - val_loss: 0.6576 - learning_rate: 0.0010
# Epoch 2/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6998 - loss: 0.6567 - val_accuracy: 0.5877 - val_loss: 0.7553 - learning_rate: 0.0010
# Epoch 3/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7271 - loss: 0.5633 - val_accuracy: 0.5826 - val_loss: 0.9573 - learning_rate: 0.0010
# Epoch 4/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7585 - loss: 0.4938 - val_accuracy: 0.5801 - val_loss: 1.4453 - learning_rate: 0.0010
# Epoch 5/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7737 - loss: 0.4617 - val_accuracy: 0.6012 - val_loss: 1.1577 - learning_rate: 0.0010
# Epoch 6/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7777 - loss: 0.4532 - val_accuracy: 0.6349 - val_loss: 1.1243 - learning_rate: 0.0010
# Epoch 7/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8137 - loss: 0.4011 - val_accuracy: 0.6551 - val_loss: 1.0254 - learning_rate: 5.0000e-04
# Epoch 8/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8200 - loss: 0.3961 - val_accuracy: 0.8086 - val_loss: 0.3798 - learning_rate: 5.0000e-04
# Epoch 9/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8217 - loss: 0.3826 - val_accuracy: 0.8280 - val_loss: 0.3527 - learning_rate: 5.0000e-04
# Epoch 10/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8300 - loss: 0.3674 - val_accuracy: 0.8322 - val_loss: 0.3535 - learning_rate: 5.0000e-04
# Epoch 11/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8331 - loss: 0.3620 - val_accuracy: 0.7681 - val_loss: 0.4705 - learning_rate: 5.0000e-04
# Epoch 12/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8280 - loss: 0.3595 - val_accuracy: 0.8491 - val_loss: 0.3337 - learning_rate: 5.0000e-04
# Epoch 13/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8220 - loss: 0.3856 - val_accuracy: 0.8600 - val_loss: 0.3038 - learning_rate: 5.0000e-04
# Epoch 14/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8414 - loss: 0.3451 - val_accuracy: 0.6332 - val_loss: 1.0045 - learning_rate: 5.0000e-04
# Epoch 15/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8358 - loss: 0.3599 - val_accuracy: 0.5750 - val_loss: 1.5343 - learning_rate: 5.0000e-04
# Epoch 16/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8414 - loss: 0.3524 - val_accuracy: 0.6265 - val_loss: 1.1220 - learning_rate: 5.0000e-04
# Epoch 17/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8257 - loss: 0.3710 - val_accuracy: 0.7251 - val_loss: 0.8324 - learning_rate: 5.0000e-04
# Epoch 18/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8458 - loss: 0.3274 - val_accuracy: 0.7386 - val_loss: 0.7712 - learning_rate: 5.0000e-04
# Epoch 19/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8476 - loss: 0.3399 - val_accuracy: 0.8516 - val_loss: 0.3054 - learning_rate: 2.5000e-04
# Epoch 20/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8516 - loss: 0.3301 - val_accuracy: 0.8651 - val_loss: 0.3089 - learning_rate: 2.5000e-04
# Epoch 21/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8468 - loss: 0.3362 - val_accuracy: 0.8212 - val_loss: 0.4144 - learning_rate: 2.5000e-04
# Epoch 22/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8443 - loss: 0.3269 - val_accuracy: 0.8575 - val_loss: 0.3090 - learning_rate: 2.5000e-04
# Epoch 23/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8536 - loss: 0.3231 - val_accuracy: 0.7960 - val_loss: 0.4801 - learning_rate: 2.5000e-04
# Epoch 24/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8478 - loss: 0.3261 - val_accuracy: 0.8659 - val_loss: 0.2935 - learning_rate: 1.2500e-04
# Epoch 25/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8611 - loss: 0.3115 - val_accuracy: 0.8583 - val_loss: 0.3079 - learning_rate: 1.2500e-04
# Epoch 26/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8544 - loss: 0.3266 - val_accuracy: 0.8651 - val_loss: 0.2929 - learning_rate: 1.2500e-04
# Epoch 27/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8526 - loss: 0.3162 - val_accuracy: 0.8339 - val_loss: 0.3953 - learning_rate: 1.2500e-04
# Epoch 28/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8627 - loss: 0.3130 - val_accuracy: 0.8718 - val_loss: 0.2963 - learning_rate: 1.2500e-04
# Epoch 29/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8546 - loss: 0.3185 - val_accuracy: 0.8491 - val_loss: 0.3627 - learning_rate: 1.2500e-04
# Epoch 30/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8542 - loss: 0.3208 - val_accuracy: 0.8634 - val_loss: 0.2972 - learning_rate: 1.2500e-04

# %%
plot_model(cnn_model,show_shapes=True, show_layer_names=True)

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 15, 64)              │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 15, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 7, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 7, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 3, 128)              │          41,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 3, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 3, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 3, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 384)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          49,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 274,568 (1.05 MB)
#  Trainable params: 91,394 (357.01 KB)
#  Non-trainable params: 384 (1.50 KB)
#  Optimizer params: 182,790 (714.03 KB)

# %% [markdown]
# # Acurácia no Conjunto de Teste

# %%
# Avaliação no conjunto de teste
cnn_predictions = cnn_model.predict(X_test)
cnn_predicted_class = np.argmax(cnn_predictions, axis=1)
cnn_true_class = np.argmax(y_test, axis=1)

# Cálculos de desempenho
cnn_accuracy = accuracy_score(cnn_true_class, cnn_predicted_class)
cnn_confusion_matrix = confusion_matrix(cnn_true_class, cnn_predicted_class)
cnn_precision = precision_score(cnn_true_class, cnn_predicted_class)
cnn_recall = recall_score(cnn_true_class, cnn_predicted_class)

print(f"CNN Accuracy: {cnn_accuracy:.2%}")
print(f"CNN Precision: {cnn_precision:.2f}")
print(f"CNN Recall: {cnn_recall:.2f}")
print("CNN Confusion Matrix:\n", cnn_confusion_matrix)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# CNN Accuracy: 86.34%
# CNN Precision: 0.85
# CNN Recall: 0.81
# CNN Confusion Matrix:
#  [[619  69]
#  [ 93 405]]

# %% [markdown]
# #Backseat

# %% [markdown]
# **Parâmetros**
#
#
# predicoes: de compra e venda.
#
#
# 1: Sinal para comprar.
#
#
# 0: Sinal para vender.
#
#
# precos: Array com os preços do ativo em cada instante de tempo.
#
#
# saldo_inicial: O saldo inicial disponível para investimento de 10.000.
#
#
# balanco: Representa o saldo em dinheiro disponível.
#
# posicao: Quantidade de ativos comprados atualmente.
#
# preco_compra: Preço do ativo no momento em que foi comprado.
#
# curva: Lista que acompanha o valor total da conta (soma de saldo e valor dos ativos) ao longo do tempo.
#
#
#
# **Explicação**
#
# Para cada instante i, o preço e a previsão (predicao[i]) são analisados.
# Compra (predicao[i] == 1):
#
# Compra o ativo caso não haja posição aberta (posicao == 0).
# Calcula a quantidade de ativos que pode ser comprada: balanco / preco_compra.
# Zera o saldo disponível (balanco).
# Venda (predicao[i] == 0):
#
# Vende o ativo caso haja posição aberta (posicao > 0).
# Calcula o saldo final após vender todos os ativos: posicao * preco_venda.
# Zera a posição.
# Atualização do valor total:
#
# Após cada iteração, o valor total da conta (dinheiro + valor da posição aberta) é calculado e armazenado em curva.
# Retorno Financeiro:
#
# Subtrai o saldo inicial do saldo final para calcular o lucro/prejuízo.

# %%
#Função de backseat para simular o desempenho de uma estratégia de trading.


def backtest(predicoes, precos, saldo_inicial=10000, return_equity_curve=False):

    balanco = saldo_inicial
    posicao = 0
    preco_compra = 0
    curva = []

    for i in range(len(predicoes)):
        if predicoes[i] == 1 and posicao == 0:  # Comprar
            preco_compra = precos[i]
            posicao = balanco / preco_compra
        elif predicoes[i] == 0 and posicao > 0:  # Vender
            preco_venda = precos[i]
            balanco = posicao * preco_venda
            posicao = 0
        curva.append(balanco + posicao * precos[i])

    if return_equity_curve:
        return curva  # Retorna a curva de equity
    else:
        return curva[-1] - saldo_inicial  # Retorna o retorno financeiro

# Carregando df novamente.
df = pd.read_csv('treino.csv')

# Obter preços do fundo de ações
precos = np.array(df['Past_1_Days_Close'].values)

# Realizar backtest para o modelo CNN
cnn_profit = backtest(cnn_predicted_class, precos)
print(f"CNN ganhos: {cnn_profit:.2f}")
# Out:
# CNN ganhos: 16151.06

# %% [markdown]
# #Gráficos e Análise

# %%
# Matriz de confusão para CNN
plt.figure(figsize=(8, 6))
sns.heatmap(cnn_confusion_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Matriz de Confusão - CNN')
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.show()

# %%
# Treinamento o modelo novamente e salvando o histórico em uma variável
history = cnn_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30, batch_size=64, callbacks=[reduce_lr])

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')  # Use 'accuracy' if available
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Use 'val_accuracy' if available
plt.title('CNN Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('CNN Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8643 - loss: 0.3057 - val_accuracy: 0.8617 - val_loss: 0.3021 - learning_rate: 1.2500e-04
# Epoch 2/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8579 - loss: 0.3103 - val_accuracy: 0.8710 - val_loss: 0.2903 - learning_rate: 1.2500e-04
# Epoch 3/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8672 - loss: 0.2921 - val_accuracy: 0.8752 - val_loss: 0.2875 - learning_rate: 1.2500e-04
# Epoch 4/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8630 - loss: 0.3010 - val_accuracy: 0.8457 - val_loss: 0.3496 - learning_rate: 1.2500e-04
# Epoch 5/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8641 - loss: 0.3069 - val_accuracy: 0.8238 - val_loss: 0.4057 - learning_rate: 1.2500e-04
# Epoch 6/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8543 - loss: 0.3187 - val_accuracy: 0.8642 - val_loss: 0.3023 - learning_rate: 1.2500e-04
# Epoch 7/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8701 - loss: 0.2942 - val_accuracy: 0.8533 - val_loss: 0.3186 - learning_rate: 1.2500e-04
# Epoch 8/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8607 - loss: 0.3040 - val_accuracy: 0.8659 - val_loss: 0.3042 - learning_rate: 1.2500e-04
# Epoch 9/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8656 - loss: 0.3004 - val_accuracy: 0.8600 - val_loss: 0.2979 - learning_rate: 6.2500e-05
# Epoch 10/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8576 - loss: 0.3095 - val_accuracy: 0.8634 - val_loss: 0.2988 - learning_rate: 6.2500e-05
# Epoch 11/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8705 - loss: 0.2953 - val_accuracy: 0.8702 - val_loss: 0.2920 - learning_rate: 6.2500e-05
# Epoch 12/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8673 - loss: 0.3089 - val_accuracy: 0.8710 - val_loss: 0.2900 - learning_rate: 6.2500e-05
# Epoch 13/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8661 - loss: 0.2966 - val_accuracy: 0.8769 - val_loss: 0.2825 - learning_rate: 6.2500e-05
# Epoch 14/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8518 - loss: 0.3185 - val_accuracy: 0.8752 - val_loss: 0.2808 - learning_rate: 6.2500e-05
# Epoch 15/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8578 - loss: 0.3087 - val_accuracy: 0.8642 - val_loss: 0.2968 - learning_rate: 6.2500e-05
# Epoch 16/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8618 - loss: 0.2932 - val_accuracy: 0.8524 - val_loss: 0.3254 - learning_rate: 6.2500e-05
# Epoch 17/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8567 - loss: 0.3060 - val_accuracy: 0.8702 - val_loss: 0.2859 - learning_rate: 6.2500e-05
# Epoch 18/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8661 - loss: 0.2937 - val_accuracy: 0.8524 - val_loss: 0.3375 - learning_rate: 6.2500e-05
# Epoch 19/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8656 - loss: 0.3006 - val_accuracy: 0.8550 - val_loss: 0.3145 - learning_rate: 6.2500e-05
# Epoch 20/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8716 - loss: 0.2843 - val_accuracy: 0.8718 - val_loss: 0.2899 - learning_rate: 3.1250e-05
# Epoch 21/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8636 - loss: 0.3005 - val_accuracy: 0.8735 - val_loss: 0.2897 - learning_rate: 3.1250e-05
# Epoch 22/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8619 - loss: 0.3045 - val_accuracy: 0.8710 - val_loss: 0.2847 - learning_rate: 3.1250e-05
# Epoch 23/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8632 - loss: 0.3068 - val_accuracy: 0.8642 - val_loss: 0.2928 - learning_rate: 3.1250e-05
# Epoch 24/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8535 - loss: 0.3029 - val_accuracy: 0.8685 - val_loss: 0.2923 - learning_rate: 3.1250e-05
# Epoch 25/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8705 - loss: 0.2916 - val_accuracy: 0.8744 - val_loss: 0.2844 - learning_rate: 1.5625e-05
# Epoch 26/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8648 - loss: 0.3018 - val_accuracy: 0.8752 - val_loss: 0.2847 - learning_rate: 1.5625e-05
# Epoch 27/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8703 - loss: 0.2852 - val_accuracy: 0.8769 - val_loss: 0.2892 - learning_rate: 1.5625e-05
# Epoch 28/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8652 - loss: 0.2957 - val_accuracy: 0.8718 - val_loss: 0.2879 - learning_rate: 1.5625e-05
# Epoch 29/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8642 - loss: 0.3029 - val_accuracy: 0.8744 - val_loss: 0.2908 - learning_rate: 1.5625e-05
# Epoch 30/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8707 - loss: 0.2942 - val_accuracy: 0.8761 - val_loss: 0.2877 - learning_rate: 1.0000e-05

# %%
cnn_equity_curve = backtest(cnn_predicted_class, precos, return_equity_curve=True)

plt.figure(figsize=(10, 6))
plt.plot(cnn_equity_curve, label='CNN Equity Curve')
plt.title('Backtest: Curva de Equity')
plt.xlabel('Período')
plt.ylabel('Saldo ($)')
plt.legend()
plt.grid()
plt.show()

# %%
metrics = ['Accuracy', 'Precision', 'Recall']
cnn_scores = [cnn_accuracy, cnn_precision, cnn_recall]
x = np.arange(len(metrics))

plt.figure(figsize=(10, 6))
plt.bar(x - 0.2, cnn_scores, width=0.4, label='CNN')
plt.xticks(x, metrics)
plt.ylim(0, 1)
plt.title('Métricas')
plt.ylabel('Score')
plt.legend()
plt.grid(axis='y')
plt.show()
